# %% [markdown]
# # Deep features via k-means
#
# The following notebook is based on the following paper
# https://www-cs.stanford.edu/~acoates/papers/coatesng_nntot2012.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
import os
import sys

import numpy as np
import pandas as pd

import scipy.stats as sstats

from sklearn import datasets
import sklearn.linear_model

from matplotlib import animation, pyplot, rc
import matplotlib.pyplot as plt

import httpimport

# %%
# !pip install -q gdown httpimport
![ -e cifar.npz ] || gdown 'https://drive.google.com/uc?id=1oBzZdtg2zNTPGhbRy6DQ_wrf5L5OAhNR&confirm=t' -O cifar.npz

# %%
with np.load('cifar.npz') as data:
    cifar_train_data = data['train_data']
    cifar_train_labels = data['train_labels']
    cifar_test_data = data['test_data']
    cifar_test_labels = data['test_labels']

# %%
# let's load data 
#(X_trn, y_trn), (X_tst, y_tst) = cifar10.load_data()
X_trn = cifar_train_data[:5000]
y_trn = cifar_train_labels[:5000]
X_tst = cifar_test_data
y_tst = cifar_test_labels

# %%
X_trn.shape
# Out:
# (5000, 32, 32, 3)

# %%
X_tst.shape
# Out:
# (10000, 32, 32, 3)

# %%
plt.figure(figsize=(12,10))
for xx in range(25):
    plt.subplot(5,5,xx+1)
    plt.imshow(X_trn[xx, :].reshape(32,32,3))
    plt.axis('off')

# %% [markdown]
# # Simple Logistic Regression

# %%
X_trn_norm = (X_trn.reshape(-1,32*32*3) - X_trn.reshape(-1,32*32*3).mean(axis=0))/X_trn.reshape(-1,32*32*3).std(axis=0)
X_tst_norm = (X_tst.reshape(-1,32*32*3) - X_trn.reshape(-1,32*32*3).mean(axis=0))/X_trn.reshape(-1,32*32*3).std(axis=0)

# %%
X_trn_norm.shape
# Out:
# (5000, 3072)

# %%
from sklearn.linear_model import LogisticRegression

clf_simple = LogisticRegression(random_state=0, max_iter=100, verbose=True, n_jobs=6).fit(X_trn_norm, y_trn.flatten())
# Out:
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 out of   1 | elapsed:   11.8s finished

# %%
y_trn_pred = clf_simple.predict(X_trn_norm)
print((y_trn.flatten() == y_trn_pred).mean())
# Out:
# 0.7574

# %%
y_tst_pred = clf_simple.predict(X_tst_norm)
print((y_tst.flatten() == y_tst_pred).mean())
# Out:
# 0.2907

# %% [markdown]
# # Deep Features

# %% [markdown]
# ## find important patterns in patches

# %%
def contrast(image):
  return (image-image.min())/(image.max() - image.min())

# %%
def normalize_patch(patch, eps=10):
  return (patch - patch.mean())/np.sqrt(patch.var() + eps)

# %%
def whiten(X):
  X_norm = (X - X.mean(axis=0))/X.std(axis=0)
  cov = np.cov(X_norm, rowvar=False) 
  U,S,V = np.linalg.svd(cov)
  
  # zca_matrix = np.dot(U, np.dot(np.diag(1.0/np.sqrt(S + epsilon)), U.T))
  X_zca = U.dot(np.diag(1.0/np.sqrt(S + 0.1))).dot(U.T).dot(X_norm.T).T
  return X_zca
  # return X

# %%
def plotImage(X):
    plt.figure(figsize=(1.5, 1.5))
    plt.imshow(X.reshape(32,32,3))
    plt.show()
    plt.close()

# %% [markdown]
# ### Let's get some intuition for what whitening does

# %%
X_zca = whiten(X_trn[:1000].reshape(-1,32*32*3))

# %%
plt.figure(figsize=(12,10))
for xx in range(25):
    plt.subplot(5,10,2*xx+1)
    plt.imshow(X_trn[xx, :].reshape(32,32,3))
    plt.axis('off')
    plt.subplot(5,10,2*xx+2)
    # plt.imshow(contrast(X_zca[xx, :]).reshape(32,32,3))
    plt.axis('off')

# %% [markdown]
# ### Back to the feature extraction

# %%
def normalize_patch(patch, eps=10):
  return (patch - patch.mean())/np.sqrt(patch.var() + eps)

# %%
PATCH_SIZE = 8
patch_num = 100000
STRIDE = 8

# %%
X_trn.shape
# Out:
# (5000, 32, 32, 3)

# %%
patches = []
for i in range(patch_num):
  for r in range(32-PATCH_SIZE+1):
    for c in range(32-PATCH_SIZE+1):
      patch = X_trn[i].reshape(32,32,3)[c:(c+PATCH_SIZE),r:(r+PATCH_SIZE)].flatten()
      patch_norm = normalize_patch(patch, eps=10)
      patches.append(patch_norm)
  if len(patches) >= patch_num:
    break

# %%
P = np.vstack(patches)
P.shape
# Out:
# (100000, 192)

# %%
P_zca = whiten(P)

# %%
plt.imshow(contrast(P[0].reshape(PATCH_SIZE, PATCH_SIZE, 3)))

# %%
# plt.imshow(contrast(P_zca[0].reshape(PATCH_SIZE, PATCH_SIZE, 3)))

# %%
kroot = 16
k = kroot*kroot

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans
import numpy as np
kmeans = MiniBatchKMeans(n_clusters=k, random_state=0, verbose=True, n_init=1, max_iter=200, batch_size=10000).fit(P_zca)
kmeans.labels_
kmeans.cluster_centers_
# Out:
# Init 1/1 with method k-means++
# Inertia for init 1/1: 2109499.9754000492
# [MiniBatchKMeans] Reassigning 139 cluster centers.
# Minibatch step 1/2000: mean batch inertia: 70.7080703447131
# [MiniBatchKMeans] Reassigning 110 cluster centers.
# Minibatch step 2/2000: mean batch inertia: 65.17018131669272, ewa inertia: 65.17018131669272
# [MiniBatchKMeans] Reassigning 93 cluster centers.
# Minibatch step 3/2000: mean batch inertia: 63.670550274599904, ewa inertia: 64.87025810750625
# [MiniBatchKMeans] Reassigning 72 cluster centers.
# Minibatch step 4/2000: mean batch inertia: 62.910234705244214, ewa inertia: 64.47825734706144
# [MiniBatchKMeans] Reassigning 61 cluster centers.
# Minibatch step 5/2000: mean batch inertia: 62.88490074294384, ewa inertia: 64.15958921291926
# [MiniBatchKMeans] Reassigning 54 cluster centers.
# Minibatch step 6/2000: mean batch inertia: 61.275135558196226, ewa inertia: 63.58270425082427
# [MiniBatchKMeans] Reassigning 47 cluster centers.
# Minibatch step 7/2000: mean batch inertia: 61.61583925691268, ewa inertia: 63.1893351857326
# [MiniBatchKMeans] Reassigning 40 cluster centers.
# Minibatch step 8/2000: mean batch inertia: 61.63386027229635, ewa inertia: 62.87824331396406
# [MiniBatchKMeans] Reassigning 29 cluster centers.
# Minibatch step 9/2000: mean batch inertia: 61.627903291457685, ewa inertia: 62.628177810117826
# [MiniBatchKMeans] Reassigning 28 cluster centers.
# Minibatch step 10/2000: mean batch inertia: 61.485906870485934, ewa inertia: 62.399725906710486
# [MiniBatchKMeans] Reassigning 29 cluster centers.
# Minibatch step 11/2000: mean batch inertia: 61.72137169326641, ewa inertia: 62.26405642071653
# [MiniBatchKMeans] Reassigning 23 cluster centers.
# Minibatch step 12/2000: mean batch inertia: 61.26437715695583, ewa inertia: 62.06412256730292
# [MiniBatchKMeans] Reassigning 21 cluster centers.
# Minibatch step 13/2000: mean batch inertia: 60.9646061292124, ewa inertia: 61.8442214786957
# [MiniBatchKMeans] Reassigning 19 cluster centers.
# Minibatch step 14/2000: mean batch inertia: 60.560469520946754, ewa inertia: 61.587473654624155
# [MiniBatchKMeans] Reassigning 19 cluster centers.
# Minibatch step 15/2000: mean batch inertia: 60.89204668430828, ewa inertia: 61.448389651401015
# [MiniBatchKMeans] Reassigning 15 cluster centers.
# Minibatch step 16/2000: mean batch inertia: 60.626660639513574, ewa inertia: 61.28404549246511
# [MiniBatchKMeans] Reassigning 14 cluster centers.
# Minibatch step 17/2000: mean batch inertia: 61.12828377597077, ewa inertia: 61.25289346068656
# [MiniBatchKMeans] Reassigning 11 cluster centers.
# Minibatch step 18/2000: mean batch inertia: 60.97102003915322, ewa inertia: 61.19651934012109
# [MiniBatchKMeans] Reassigning 3 cluster centers.
# Minibatch step 19/2000: mean batch inertia: 60.50231912599731, ewa inertia: 61.05768068568288
# [MiniBatchKMeans] Reassigning 6 cluster centers.
# Minibatch step 20/2000: mean batch inertia: 60.387542891709835, ewa inertia: 60.923654467150456
# [MiniBatchKMeans] Reassigning 10 cluster centers.
# Minibatch step 21/2000: mean batch inertia: 61.10245094128337, ewa inertia: 60.95941340438766
# [MiniBatchKMeans] Reassigning 9 cluster centers.
# Minibatch step 22/2000: mean batch inertia: 59.72790373224819, ewa inertia: 60.713113932954485
# [MiniBatchKMeans] Reassigning 6 cluster centers.
# Minibatch step 23/2000: mean batch inertia: 60.38297023363267, ewa inertia: 60.64708585337092
# [MiniBatchKMeans] Reassigning 9 cluster centers.
# Minibatch step 24/2000: mean batch inertia: 60.55571013003544, ewa inertia: 60.62881089145344
# Minibatch step 25/2000: mean batch inertia: 60.51154712873383, ewa inertia: 60.6053583734347
# Minibatch step 26/2000: mean batch inertia: 60.09651727875853, ewa inertia: 60.503591172171475
# Minibatch step 27/2000: mean batch inertia: 61.21655711894636, ewa inertia: 60.64618293560882
# [MiniBatchKMeans] Reassigning 3 cluster centers.
# Minibatch step 28/2000: mean batch inertia: 60.02986041047047, ewa inertia: 60.52291966321388
# [MiniBatchKMeans] Reassigning 3 cluster centers.
# Minibatch step 29/2000: mean batch inertia: 59.841220811352485, ewa inertia: 60.38658125622567
# [MiniBatchKMeans] Reassigning 3 cluster centers.
# Minibatch step 30/2000: mean batch inertia: 60.5379166488466, ewa inertia: 60.4168480320821
# [MiniBatchKMeans] Reassigning 4 cluster centers.
# Minibatch step 31/2000: mean batch inertia: 60.860933360740624, ewa inertia: 60.505664209652025
# [MiniBatchKMeans] Reassigning 3 cluster centers.
# Minibatch step 32/2000: mean batch inertia: 60.28610730085912, ewa inertia: 60.46175326700287
# Minibatch step 33/2000: mean batch inertia: 59.979127993630314, ewa inertia: 60.365229177569255
# Minibatch step 34/2000: mean batch inertia: 59.19702052070919, ewa inertia: 60.13158978259119
# [MiniBatchKMeans] Reassigning 3 cluster centers.
# Minibatch step 35/2000: mean batch inertia: 59.68991812609525, ewa inertia: 60.04325633462648
# Minibatch step 36/2000: mean batch inertia: 59.79954161225371, ewa inertia: 59.994513877576495
# Minibatch step 37/2000: mean batch inertia: 59.47271707877112, ewa inertia: 59.89015556139858
# Minibatch step 38/2000: mean batch inertia: 59.361695260828604, ewa inertia: 59.784464558194614
# Minibatch step 39/2000: mean batch inertia: 59.82629519794673, ewa inertia: 59.79283060248459
# Minibatch step 40/2000: mean batch inertia: 59.52654260295962, ewa inertia: 59.73957353515027
# Minibatch step 41/2000: mean batch inertia: 60.06793729340518, ewa inertia: 59.80524563008031
# Minibatch step 42/2000: mean batch inertia: 60.75077625370778, ewa inertia: 59.99434986376346
# Minibatch step 43/2000: mean batch inertia: 59.607527409506964, ewa inertia: 59.916986146549334
# Minibatch step 44/2000: mean batch inertia: 59.72694296559127, ewa inertia: 59.87897789044028
# Minibatch step 45/2000: mean batch inertia: 59.9062717053039, ewa inertia: 59.88443659882592
# Minibatch step 46/2000: mean batch inertia: 59.16336827842606, ewa inertia: 59.74022437686817
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# Minibatch step 47/2000: mean batch inertia: 59.6626120660279, ewa inertia: 59.72470206992318
# Minibatch step 48/2000: mean batch inertia: 60.55655370844799, ewa inertia: 59.891070733941504
# Minibatch step 49/2000: mean batch inertia: 59.6499205323728, ewa inertia: 59.84284117592335
# Minibatch step 50/2000: mean batch inertia: 60.13872980693567, ewa inertia: 59.902018310354464
# Minibatch step 51/2000: mean batch inertia: 59.54555345997339, ewa inertia: 59.83072605320082
# Minibatch step 52/2000: mean batch inertia: 59.56515885238436, ewa inertia: 59.77761314416662
# Minibatch step 53/2000: mean batch inertia: 59.88340347722458, ewa inertia: 59.79877099919966
# Minibatch step 54/2000: mean batch inertia: 59.492753650730826, ewa inertia: 59.73756814153447
# Minibatch step 55/2000: mean batch inertia: 60.56130546428149, ewa inertia: 59.9023139586257
# Minibatch step 56/2000: mean batch inertia: 59.651804066607774, ewa inertia: 59.85221248123689
# Minibatch step 57/2000: mean batch inertia: 59.843188670594465, ewa inertia: 59.85040773715585
# Converged (lack of improvement in inertia) at step 57/2000
# array([[-0.7420887 ,  0.12057546,  0.51937191, ..., -0.08523162,
#          0.00797352,  0.05768645],
#        [ 0.37718515,  0.43146144,  0.3796663 , ...,  0.05250999,
#          0.08430437,  0.10166177],
#        [ 0.05196916,  0.06773251,  0.07508605, ...,  0.02675208,
#          0.00409205, -0.00874966],
#        ...,
#        [ 0.04172806,  0.06818469,  0.19536284, ...,  0.04592895,
#          0.08665942, -0.043457  ],
#        [-0.09402851, -0.13701554, -0.12147064, ...,  0.01175114,
#         -0.01079738, -0.038617  ],
#        [ 0.65126127, -0.6340046 , -1.13409332, ..., -0.1388568 ,
#          0.04309452,  0.23013285]])

# %%
filters_final = kmeans.cluster_centers_
filters_final.shape
# Out:
# (256, 192)

# %%
plt.figure(figsize=(kroot,kroot))
for xx in range(k):
    plt.subplot(kroot,kroot,xx+1)
    plt.imshow((contrast(filters_final[xx])).reshape(PATCH_SIZE, PATCH_SIZE, 3), cmap=plt.get_cmap('gray'))
    plt.axis('off')

# %% [markdown]
# # transform dataset according to the patterns found in patches

# %%
def dist(x,y):
  return np.sqrt((x - y).dot(x-y))
  #return (x-y).dot(x-y)
    
def create_patch_features(X):    
    X_mapped_list_per_image = []
    for i in range(X.shape[0]):
      if i % 1000 == 0:
        print(i,"/", X.shape[0])
        
      mapped_features = []
      for r in range(0, 32-PATCH_SIZE+1, STRIDE):
        for c in range(0, 32-PATCH_SIZE+1, STRIDE):
          patch = X[i].reshape(32,32,3)[c:(c+PATCH_SIZE),r:(r+PATCH_SIZE)].flatten()
          patch_norm = normalize_patch(patch, eps=0.01)
          mapped_features.append([dist(patch_norm, f) for f in filters_final])
      X_mapped_list_per_image.append(np.vstack(mapped_features))
    X_mapped = np.asarray(X_mapped_list_per_image).reshape(-1, ((32-PATCH_SIZE)//STRIDE+1)**2*filters_final.shape[0])
    return X_mapped

# %%
from sklearn.feature_extraction import image
from sklearn.metrics import pairwise_distances
from sklearn.metrics.pairwise import euclidean_distances

def create_patch_features__vectorized(X):    
    X_mapped_list_per_image = []
    for i in range(X.shape[0]):
        if i % 5000 == 0:
            print(i,"/", X.shape[0])
        patches = image.extract_patches_2d(X[i], (PATCH_SIZE, PATCH_SIZE))
        strided_patches = patches.reshape( 32-PATCH_SIZE+1 , 32-PATCH_SIZE+1, PATCH_SIZE, PATCH_SIZE, 3)[::STRIDE,::STRIDE,:,:,:]
        strided_patches = strided_patches.reshape(((32-PATCH_SIZE)//STRIDE+1)**2, PATCH_SIZE * PATCH_SIZE * 3)
        mapped_features = euclidean_distances(np.asarray([normalize_patch(patch, eps=0.01) for patch in strided_patches]), filters_final)
        X_mapped_list_per_image.append(mapped_features.reshape(((32-PATCH_SIZE)//STRIDE+1)**2 * filters_final.shape[0]))
    X_mapped = np.asarray(X_mapped_list_per_image)
    return X_mapped

# %%
X_mapped_trn = create_patch_features__vectorized(X_trn)
# Out:
# 0 / 5000

# %%
X_mapped_trn.shape
# Out:
# (5000, 4096)

# %%
X_mapped_tst = create_patch_features__vectorized(X_tst)
# Out:
# 0 / 10000
# 5000 / 10000

# %%
X_mapped_tst.shape
# Out:
# (10000, 4096)

# %% [markdown]
# # Logistic Regression on mapped features

# %%
X_mapped_trn_norm = (X_mapped_trn - X_mapped_trn.mean(axis=0))/X_mapped_trn.std(axis=0)
# X_mapped_trn_norm = X_mapped_trn

# %%
X_mapped_tst_norm = (X_mapped_tst - X_mapped_trn.mean(axis=0))/X_mapped_trn.std(axis=0)
# X_mapped_tst_norm = X_mapped_tst

# %%
X_mapped_trn_norm.std(axis=0).sum()
# Out:
# 4096.0

# %%
X_mapped_tst_norm.std(axis=0).sum()
# Out:
# 4121.809139715351

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
# clf = LogisticRegression(random_state=0, max_iter=100, n_jobs=10, verbose=True).fit(X_mapped_trn_norm, y_trn.flatten())
clf = KNeighborsClassifier(n_neighbors = 10).fit(X_mapped_trn_norm, y_trn.flatten())

# %%
y_trn_pred = clf.predict(X_mapped_trn_norm)
(y_trn.flatten() == y_trn_pred).mean()
# Out:
# 0.4744

# %%
y_tst_pred = clf.predict(X_mapped_tst_norm)
(y_tst.flatten() == y_tst_pred).mean()
# Out:
# 0.3544
